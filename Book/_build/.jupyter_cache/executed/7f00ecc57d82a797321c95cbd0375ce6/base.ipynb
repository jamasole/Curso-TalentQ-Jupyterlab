# %%
import sys
sys.path.append('../')
import macro_tQ as tQ

import numpy as np
import scipy.linalg as la
from IPython.display import display,Markdown,Latex
import matplotlib.pyplot as plt
from qiskit.tools.visualization import array_to_latex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append('../')
# ----> 3 import macro_tQ as tQ
#       5 import numpy as np
#       6 import scipy.linalg as la
#
# ModuleNotFoundError: No module named 'macro_tQ'

# %%
'''ángulo que queremos rotar'''
theta=0.6 

'''vector a rotar'''
u1=2.
u2=2.

'''v1 y v2 a partir de u1, u2 y theta'''
def R(u1,u2,theta):
        u = u1 + u2*1j
        v = u*np.exp(1j*theta) # u rotado un angulo theta
        return v.real,v.imag
    
v1,v2 =  R(u1,u2,theta)

''' Representación en el plano complejo '''
v = v1**2+v2**2
tQ.plot_2D_plane(left=-int(abs(v1))-2,right=int(abs(v1))+2,up=int(abs(v2))+1,down=-int(abs(v2))-1)
tQ.draw_vector(u1,u1,vcolor='b')
tQ.draw_vector(v1,v2,vcolor='r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#      11         v = u*np.exp(1j*theta) # u rotado un angulo theta
#      12         return v.real,v.imag
# ---> 14 v1,v2 =  R(u1,u2,theta)
#      16 ''' Representación en el plano complejo '''
#      17 v = v1**2+v2**2
#
# Cell In[2], line 11, in R(u1, u2, theta)
#       9 def R(u1,u2,theta):
#      10         u = u1 + u2*1j
# ---> 11         v = u*np.exp(1j*theta) # u rotado un angulo theta
#      12         return v.real,v.imag
#
# NameError: name 'np' is not defined

# %%
U=np.matrix([[1,1J],[1J, + 1]])/np.sqrt(2)
array_to_latex(U)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 U=np.matrix([[1,1J],[1J, + 1]])/np.sqrt(2)
#       2 array_to_latex(U)
#
# NameError: name 'np' is not defined

# %%
Uadj=U.getH() # getH es un método de la clase matrix que devuelve la matriz conjugada hermítica
array_to_latex(Uadj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Uadj=U.getH() # getH es un método de la clase matrix que devuelve la matriz conjugada hermítica
#       2 array_to_latex(Uadj)
#
# NameError: name 'U' is not defined

# %%
print('comprobamos que U es unitaria')

array_to_latex(np.dot(Uadj,U))
# Out:
# comprobamos que U es unitaria
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 print('comprobamos que U es unitaria')
# ----> 3 array_to_latex(np.dot(Uadj,U))
#
# NameError: name 'array_to_latex' is not defined

# %%
d = 3

' generate a random vector'
u = tQ.random_ket(d)
display(array_to_latex(u))

' build the parallel and perpendicular projectors'
P_par = tQ.ket_bra(u,u);
P_perp = np.identity(d) - P_par

display(array_to_latex(P_par))
display(array_to_latex(P_perp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 d = 3
#       3 ' generate a random vector'
# ----> 4 u = tQ.random_ket(d)
#       5 display(array_to_latex(u))
#       7 ' build the parallel and perpendicular projectors'
#
# NameError: name 'tQ' is not defined

# %%
' check properties P^2 = P, and orthogonality '
A = P_par@P_par - P_par
B = P_perp@P_perp - P_perp
C = P_par@P_perp

display(array_to_latex(C))


' obtain parallel and perpendicular components of another vector'
v = tQ.random_ket(d)

v_par = np.dot(P_par,v)
v_perp = np.dot(P_perp,v)

' check perpendicularity'
print(np.round(tQ.braket(v_par,v_perp),4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 ' check properties P^2 = P, and orthogonality '
# ----> 2 A = P_par@P_par - P_par
#       3 B = P_perp@P_perp - P_perp
#       4 C = P_par@P_perp
#
# NameError: name 'P_par' is not defined

# %%
d = 2
' en general una matriz no será normal '
A = np.matrix(np.random.rand(d,d)+ np.random.rand(d,d) * 1j)
display(array_to_latex(np.dot(A,A.getH()) - np.dot(A.getH(),A)))

eigvals, eigvecs = np.linalg.eig(A)
print('valprop =',eigvals)

'verificamos que los autovectores son las columnas de v'
m=1 #cambiar a otro valor
display(array_to_latex(np.dot(A, eigvecs[:, m]) - eigvals[m] * eigvecs[:, m],prefix=r'A|\lambda_m \rangle -\lambda_m |\lambda_m\rangle =  '))

' diagonalizamos A '
U = np.matrix(eigvecs);

array_to_latex(np.dot(U.getI(),np.dot(A,U)),prefix='A_{diag} = U^{-1} A U = ')

'U no es unitaria'
array_to_latex(np.dot(U,U.getH()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 d = 2
#       2 ' en general una matriz no será normal '
# ----> 3 A = np.matrix(np.random.rand(d,d)+ np.random.rand(d,d) * 1j)
#       4 display(array_to_latex(np.dot(A,A.getH()) - np.dot(A.getH(),A)))
#       6 eigvals, eigvecs = np.linalg.eig(A)
#
# NameError: name 'np' is not defined

# %%
d = 2
'veamos ahora una matriz normal'
A = np.matrix([[1, -1], [1, 1]])
display(array_to_latex(np.dot(A,A.getH()) - np.dot(A.getH(),A)))


eigvals, eigvecs = np.linalg.eig(A)
print('valprop =',eigvals)

'verificamos que los autovectores son las columnas de v'
m=1 #cambiar a otro valor
display(array_to_latex(np.dot(A, eigvecs[:, m]) - eigvals[m] * eigvecs[:, m],prefix=r'A|\lambda_m \rangle -\lambda_m |\lambda_m\rangle =  '))

' diagonalizamos A '
U = np.matrix(eigvecs);

array_to_latex(np.dot(U.getH(),np.dot(A,U)),prefix='A_{diag} = U^{\dagger} A U = ')

'U es unitaria'
array_to_latex(np.dot(U,U.getH()))
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\d'
# <>:17: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_26005/3458884779.py:17: SyntaxWarning: invalid escape sequence '\d'
#   array_to_latex(np.dot(U.getH(),np.dot(A,U)),prefix='A_{diag} = U^{\dagger} A U = ')
# /tmp/ipykernel_26005/3458884779.py:17: SyntaxWarning: invalid escape sequence '\d'
#   array_to_latex(np.dot(U.getH(),np.dot(A,U)),prefix='A_{diag} = U^{\dagger} A U = ')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 d = 2
#       2 'veamos ahora una matriz normal'
# ----> 3 A = np.matrix([[1, -1], [1, 1]])
#       4 display(array_to_latex(np.dot(A,A.getH()) - np.dot(A.getH(),A)))
#       7 eigvals, eigvecs = np.linalg.eig(A)
#
# NameError: name 'np' is not defined

# %%
A = np.array([[1, 1], [-1, 1]])
array_to_latex(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 A = np.array([[1, 1], [-1, 1]])
#       2 array_to_latex(A)
#
# NameError: name 'np' is not defined

# %%
' Realizamos la descomposición espectral'
eigvals, eigvecs = np.linalg.eig(A)

eigvec0 = eigvecs[:,0]
P0 = tQ.ket_bra(eigvec0,eigvec0)
display(array_to_latex(P0,prefix='P_0='))

eigvec1 = eigvecs[:,1]
P1 = tQ.ket_bra(eigvec1,eigvec1)
display(array_to_latex(P1,prefix='P_1='))

'verificamos completitud'
array_to_latex(P0+P1,prefix='P_0 + P_1=')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 ' Realizamos la descomposición espectral'
# ----> 2 eigvals, eigvecs = np.linalg.eig(A)
#       4 eigvec0 = eigvecs[:,0]
#       5 P0 = tQ.ket_bra(eigvec0,eigvec0)
#
# NameError: name 'np' is not defined

# %%
A_descomp_espect = eigvals[0]*P0+eigvals[1]*P1

array_to_latex(A_descomp_espect)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 A_descomp_espect = eigvals[0]*P0+eigvals[1]*P1
#       3 array_to_latex(A_descomp_espect)
#
# NameError: name 'eigvals' is not defined

# %%
'''Método para construir una matriz unitaria arbitraria usando la descomposición polar'''
d = 3
A = np.matrix(np.random.rand(d,d)+ np.random.rand(d,d) * 1j)

#u, s, vh = linalg.svd(A, full_matrices=False)
u,r = la.polar(A)
    
R = np.matrix(r) 
' verificamos que R sólo tiene autovalores no-negativos '
Reigval, Reigvec = la.eig(R)
print(np.round(Reigval,3))

U=np.matrix(u) 
Display('$U = %s$'%MatrixToLatex(U))

''' Verifiquemos unitariedad '''
Display('$U^{\dagger}U = %s$'%MatrixToLatex(np.dot(U.getH(),U)))

''' verificamos que los autovalores de U son fases'''
np.round([la.eig(U)[0][i]*la.eig(U)[0][i].conjugate() for i in range(d)],5)
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\d'
# <>:17: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_26005/2106388723.py:17: SyntaxWarning: invalid escape sequence '\d'
#   Display('$U^{\dagger}U = %s$'%MatrixToLatex(np.dot(U.getH(),U)))
# /tmp/ipykernel_26005/2106388723.py:17: SyntaxWarning: invalid escape sequence '\d'
#   Display('$U^{\dagger}U = %s$'%MatrixToLatex(np.dot(U.getH(),U)))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 '''Método para construir una matriz unitaria arbitraria usando la descomposición polar'''
#       2 d = 3
# ----> 3 A = np.matrix(np.random.rand(d,d)+ np.random.rand(d,d) * 1j)
#       5 #u, s, vh = linalg.svd(A, full_matrices=False)
#       6 u,r = la.polar(A)
#
# NameError: name 'np' is not defined

# %%
' numpy tiene la función svd para descomponer en valores singulares'

A = np.random.randn(3,2)+ 1j*np.random.randn(3,2)
display(array_to_latex(A,prefix='A='))
print( 'the shape of A is :', A.shape)


u, s, vh = la.svd(A, full_matrices=True)

print( 'the shape of u =',u.shape, ' s =', s.shape,' v =', vh.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 ' numpy tiene la función svd para descomponer en valores singulares'
# ----> 3 A = np.random.randn(3,2)+ 1j*np.random.randn(3,2)
#       4 display(array_to_latex(A,prefix='A='))
#       5 print( 'the shape of A is :', A.shape)
#
# NameError: name 'np' is not defined

# %%
U=np.matrix(u)
S=np.matrix(np.diag(s))
V=np.matrix(vh).getH()

display(array_to_latex(U,prefix='U='))
display(array_to_latex(S,prefix='S='))
display(array_to_latex(V,prefix='V='))

'''Verifiquemos unitariedad'''
display(array_to_latex(np.dot(U.getH(),U),prefix='U^{\dagger}U ='))
display(array_to_latex(np.dot(V.getH(),V),prefix='V^{\dagger}V ='))
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_26005/582162267.py:10: SyntaxWarning: invalid escape sequence '\d'
#   display(array_to_latex(np.dot(U.getH(),U),prefix='U^{\dagger}U ='))
# /tmp/ipykernel_26005/582162267.py:11: SyntaxWarning: invalid escape sequence '\d'
#   display(array_to_latex(np.dot(V.getH(),V),prefix='V^{\dagger}V ='))
# /tmp/ipykernel_26005/582162267.py:10: SyntaxWarning: invalid escape sequence '\d'
#   display(array_to_latex(np.dot(U.getH(),U),prefix='U^{\dagger}U ='))
# /tmp/ipykernel_26005/582162267.py:11: SyntaxWarning: invalid escape sequence '\d'
#   display(array_to_latex(np.dot(V.getH(),V),prefix='V^{\dagger}V ='))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 U=np.matrix(u)
#       2 S=np.matrix(np.diag(s))
#       3 V=np.matrix(vh).getH()
#
# NameError: name 'np' is not defined

# %%
s0 = np.matrix([[1,0],[0,1]])
s1 = np.matrix([[0,1],[1,0]])
s2 = np.matrix([[0,-1j],[1j,0]])
s3 = np.matrix([[1,0],[0,-1]])


'verifica todas las opciones'
print(s1*s1==s0)
print(s1*s2==1j*s3)
print(s2*s1==-1j*s3)
print(s2*s1*s2==-s1)
print(s1*s1==s0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s0 = np.matrix([[1,0],[0,1]])
#       2 s1 = np.matrix([[0,1],[1,0]])
#       3 s2 = np.matrix([[0,-1j],[1j,0]])
#
# NameError: name 'np' is not defined

# %%
from scipy.linalg import expm


avec = np.random.rand(3)
a = np.linalg.norm(avec)
nvec = avec/a
print('a=',a)
display(array_to_latex(nvec))

sigvec = np.array([s1,s2,s3])


adots= sum(list(avec[i]*sigvec[i] for i in range(3)))

'exponentiating'
e1 = expm(1j*adots)

'using the Euler-like formula'
ndots= sum(list(nvec[i]*sigvec[i] for i in range(3)))
e2 = np.cos(a)*s0 + 1j*np.sin(a)*(nvec[0]*sigvec[0]+nvec[1]*sigvec[1]+nvec[2]*sigvec[2])

'verify'
display(array_to_latex(e1,prefix='exp(s1)='))
display(array_to_latex(e2,prefix='exp(s1)='))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 from scipy.linalg import expm
# ----> 4 avec = np.random.rand(3)
#       5 a = np.linalg.norm(avec)
#       6 nvec = avec/a
#
# NameError: name 'np' is not defined
