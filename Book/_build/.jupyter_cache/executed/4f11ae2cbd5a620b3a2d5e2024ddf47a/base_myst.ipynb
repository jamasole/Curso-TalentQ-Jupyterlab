# %%
> {sub-ref}`today` | {sub-ref}`wordcount-minutes` min read

import sys
sys.path.append('../')
import macro_tQ as tQ

import numpy as np
import scipy.linalg as la
from IPython.display import display,Markdown,Latex
import matplotlib.pyplot as plt
from qiskit.tools.visualization import array_to_latex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append('../')
# ----> 3 import macro_tQ as tQ
#       5 import numpy as np
#       6 import scipy.linalg as la
#
# ModuleNotFoundError: No module named 'macro_tQ'

# %%
# Veamos el caso genérico 

d1=4 # Dimensión de H1
d2=3 # Dimensión de H2

' generate a random complex matrix '
w = np.random.randn(d1,d2)+ np.random.randn(d1,d2) * 1j  # coeficientes w_{ia} de un estado genérico
display(array_to_latex(w))

' perform the SVD decomposition'
u, s, vh = np.linalg.svd(w, full_matrices=True)

np.round(s,3)

print('principal values s_i = ',np.round(s,3))
print('The Schmidt number is r =', np.count_nonzero(s))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 d2=3 # Dimensión de H2
#       6 ' generate a random complex matrix '
# ----> 7 w = np.random.randn(d1,d2)+ np.random.randn(d1,d2) * 1j  # coeficientes w_{ia} de un estado genérico
#       8 display(array_to_latex(w))
#      10 ' perform the SVD decomposition'
#
# NameError: name 'np' is not defined

# %%
# Veamos ahora el caso particular de un estado factorizable

d1=5
d2=3

' create two random vectors '
u = tQ.random_ket(d1)
v = tQ.random_ket(d2)

w = np.outer(u,v)
display(array_to_latex(w))

' SVG decomposition '
u, s, vh = np.linalg.svd(w, full_matrices=True)

print('principal values s_i = ',np.round(s,3))
print('The Schmidt number is p =', np.count_nonzero(np.round(s,3)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 d2=3
#       6 ' create two random vectors '
# ----> 7 u = tQ.random_ket(d1)
#       8 v = tQ.random_ket(d2)
#      10 w = np.outer(u,v)
#
# NameError: name 'tQ' is not defined
